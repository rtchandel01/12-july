# %% [markdown]
# <a href="https://colab.research.google.com/github/rtchandel01/12-july/blob/main/sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-510b9630-3996-487d-a704-9b9d91d86728" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-510b9630-3996-487d-a704-9b9d91d86728">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('sales_data.csv')

# %%
df
# Out:
#     Unnamed: 0 ProductID  QuantitySold      Price  Discount     Category  \
# 0            0         C             8  75.539471  0.064576         Toys
# 1            1         A             8  43.100482  0.142251         Toys
# 2            2         C             3  66.907525  0.198508     Clothing
# 3            3         C             1  67.017674  0.071013         Home
# 4            4         A             8  58.219722  0.127749         Toys
# ..         ...       ...           ...        ...       ...          ...
# 95          95         A             7  25.254347  0.060585         Toys
# 96          96         A             4  60.112114  0.146363         Toys
# 97          97         C             7  94.253930  0.053977  Electronics
# 98          98         A             8  72.642682  0.137866  Electronics
# 99          99         A             1  61.305505  0.191035         Home
#
#      Supplier        Date  CustomerID Country     Profit
# ...

# %%
product_revenue = df.groupby('ProductID')['Profit'].sum() #total revenue folr each product
product_revenue
# Out:
# ProductID
# A    546.921379
# B    525.741380
# C    458.429383
# Name: Profit, dtype: float64

# %%
overall_revenue = df['Profit'].sum() #total revenue of overall
overall_revenue
# Out:
# 1531.0921423716168

# %%
avg_profit_margin = df.groupby('ProductID')['Profit'].mean() / df.groupby('ProductID')['Price'].mean() #avg profit margin
avg_profit_margin
# Out:
# ProductID
# A    0.289795
# B    0.271351
# C    0.249943
# dtype: float64

# %%
quantity_sold = df.groupby('ProductID')['QuantitySold'].sum() #total quantity sold for each product
quantity_sold
# Out:
# ProductID
# A    154
# B    172
# C    164
# Name: QuantitySold, dtype: int64

# %%
top_selling_products = product_quantity_sold.sort_values(ascending=False).head(5)
category_quantity_sold = df.groupby('Category')['QuantitySold'].sum()
top_selling_categories = category_quantity_sold.sort_values(ascending=False).head(5)
top_selling_categories
# Out:
# Category
# Electronics    160
# Toys           148
# Home           111
# Clothing        71
# Name: QuantitySold, dtype: int64
